# %%
import pandas as pd

# Adjust pandas options to see all columns and to read subgroup descriptions fully
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 200)

# %%
df = pd.read_csv('Calc.csv')

# %%
df["FinalExam", "WeeklyTests"].to_numeric(errors='coerce', inplace=True)

# %%
df.head()
# Out:
#   course_code  collegeyear FinalExam WeeklyTests StartTest Midterm  \
# 0       2WAB0         2024       0.4         0.0       2.0     1.0
# 1       2WAB0         2024       0.7         0.7       3.5     3.5
# 2       2WAB0         2024       0.7        10.0       6.0     6.0
# 3       2WAB0         2024       0.7         6.9       6.0     2.8
# 4       2WAB0         2024       0.7         7.8       5.0     1.8
#
#    CalculatedNumericResult EndResult  Passed    origin    sex  \
# 0                      0.6       NVD   False  ORIGIN_N  SEX_V
# 1                      1.3       NVD   False  ORIGIN_E  SEX_V
# 2                      2.7       NVD   False  ORIGIN_E  SEX_V
# 3                      2.1       NVD   False  ORIGIN_N  SEX_M
# 4                      2.0       NVD   False  ORIGIN_E  SEX_M
#
#                                           croho type_vooropleiding  \
# 0  B Architecture, Urbanism & Building Sciences                VWO
# ...

# %%
df = df[df["collegejaar"]==2024]

# %%
df = df[df["cursus"]=='2WBB0']

# %%
df
# Out:
#       student_key cursus  collegejaar FinalExam WeeklyTests StartTest Midterm  \
# 0             114  2WBB0         2024       2,3        10,0       6,5     0,0
# 2            1997  2WBB0         2024       3,5         9,0       5,5     1,5
# 4            5608  2WBB0         2024       5,0        10,0       7,5     5,8
# 6            6089  2WBB0         2024       5,0         8,4       7,5     5,8
# 7           10643  2WBB0         2024       6,1        10,0       5,0     1,8
# ...           ...    ...          ...       ...         ...       ...     ...
# 3984       187853  2WBB0         2024       3,9         3,3       8,5     7,0
# 3986       187858  2WBB0         2024       5,5         8,0       9,0     5,0
# 3989       187902  2WBB0         2024       3,0         7,4       8,0     5,3
# 3991       187920  2WBB0         2024       7,3         8,0       8,0     1,6
# 3993       187971  2WBB0         2024       6,8        10,0       9,5     6,8
#
# ...

# %%
df.to_csv('data_calculus_final.csv',index=False)
